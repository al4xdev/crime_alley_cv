# %%
from core.core import Core

a = Core.setup()\
    .setup_paths()\
    .fetch_github_username()\
    .fetch_user_repositories()\
    .clone_repositories()

# %%
a.session_id
# Out:
# '25490459-cc52-4780-9c1e-dd77c96a9512'
